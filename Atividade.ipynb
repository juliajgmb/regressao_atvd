# %% [markdown]
# Exercicios do Final do Arquivo de Regressão Linear

# %% [markdown]
# 1. Explique o objetivo principal da regressão linear e como ela se diferencia da classificação em termos do tipo de saída que cada técnica busca prever.

# %% [markdown]
#  O objetivo principal da Regressão Linear é ter um modelo matematico capaz de prever a partir de dados historicos o que virá a acontecer no proximo ano ou mês, etc. Já a classificação tem como objetivo separare os dados em caixinhas a partir das caracteristicas dos dados, para ai prever dados futuros e quais suas respectivas caixas.
#  Tipos de Saída:
#  - Regressão: Um número real
#  - Classificação: Uma etiqueta ou rótulo

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Adicionar esse componente com o valor fixo de 1 é um artificio para simplificar a equação para que a equação trate o Bias junto à própria equação. O bias tem como papel ser o termo de deslocamento, dando liberdade ao modelo de deslocar a linha de separação para qualquer lugar do gráfico.

# %% [markdown]
# 3. Apresente a fórmula para o cálculo do vetor de pesos 𝑤 que minimiza o erro  quadrático médio na regressão linear, utilizando a pseudo-inversa da matriz de entrada X. Explique brevemente cada componente da fórmula.

# %% [markdown]
# Essa fórmula é a da Equação Normal, que fornece uma solução fechada para encontrar o vetor w sem precisar de loops iterativos
# $$w = (X^T X)^{-1} X^T y$$
#
# - w: Vetor de Pesos(resultado final)
# - y: Vetor de rótulos
# - X: Matriz de Entrada
# - X**T: Transposta de X
# - X**T * X: Matriz de Gram
